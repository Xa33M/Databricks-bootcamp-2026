# %% [markdown]
# # Reading from the csv file

# %%
df = (spark.read.option('header', 'true')
    .option('inferSchema', 'true')
    .csv('/Volumes/workspace/bronze_layer/source_systems/source_crm/cust_info.csv')
)

display(df)

# %% [markdown]
# # Writing to the bronze layer

# %%
df.write.mode('overwrite').saveAsTable('bronze_layer.crm_cust_info')

# %%
df = (spark.read.option('header', 'true')
    .option('inferSchema', 'true')
    .csv('/Volumes/workspace/bronze_layer/source_systems/source_crm/prd_info.csv')
)

display(df)

df.write.mode('overwrite').saveAsTable('bronze_layer.crm_prd_info')
